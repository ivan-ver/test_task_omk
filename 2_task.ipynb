# %%
import random
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns

# %%
deck = [i for i in range(1, 53)]

# %%
result = []
aces_num = [13, 26, 39, 52]
for i in range(900000):
    random.shuffle(deck)
    for j, k in enumerate(deck):
        if k in aces_num:
            result.append(j)
            break

# %%
fig, axes = plt.subplots(figsize=(10, 10))

axes.hist(x=result, bins=40)
axes.set_title('calls')
axes.grid()
